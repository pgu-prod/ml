# %% [markdown]
# # Домашнее задание
# 1. Тщательно изучите документацию на библиотеку pandas и попробуйте самостоятельно выполнить группировку по другим столбцам.
# 2. В качестве упражнения выведите на экран название (Name) фирмы, у которой цена (Price) входит в интервал Exclusive
# 3. Загружаем выборку `car.csv`
# 4. Выводим первый и третий столбцы, сначала по отдельности, потом вместе.
# 5. Вывести 10 первых строк, вывести 23 случайных строк.
# 6. Выводим статистику по числовым показателям
# 7. Сгрупируйте данные по столбцу Setosa

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('../dataset/car.csv', delimiter=',')
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %% [markdown]
# Выводим первый и третий столбцы, сначала по отдельности, потом вместе.

# %%
data.iloc[:,1]
# Out:
# 0        1 Series M
# 1          1 Series
# 2          1 Series
# 3          1 Series
# 4          1 Series
#             ...
# 11909           ZDX
# 11910           ZDX
# 11911           ZDX
# 11912           ZDX
# 11913        Zephyr
# Name: Model, Length: 11914, dtype: object

# %%
data.iloc[:,3]
# Out:
# 0           premium unleaded (required)
# 1           premium unleaded (required)
# 2           premium unleaded (required)
# 3           premium unleaded (required)
# 4           premium unleaded (required)
#                       ...
# 11909       premium unleaded (required)
# 11910       premium unleaded (required)
# 11911       premium unleaded (required)
# 11912    premium unleaded (recommended)
# 11913                  regular unleaded
# Name: Engine Fuel Type, Length: 11914, dtype: object

# %%
data.iloc[:,[1,3]]
# Out:
#             Model                Engine Fuel Type
# 0      1 Series M     premium unleaded (required)
# 1        1 Series     premium unleaded (required)
# 2        1 Series     premium unleaded (required)
# 3        1 Series     premium unleaded (required)
# 4        1 Series     premium unleaded (required)
# ...           ...                             ...
# 11909         ZDX     premium unleaded (required)
# 11910         ZDX     premium unleaded (required)
# 11911         ZDX     premium unleaded (required)
# 11912         ZDX  premium unleaded (recommended)
# 11913      Zephyr                regular unleaded
#
# [11914 rows x 2 columns]

# %% [markdown]
# Вывести 10 первых строк, вывести 23 случайных строк.

# %%
data.iloc[:10,:]
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
# 5               6.0            MANUAL  rear wheel drive              2.0
# 6               6.0            MANUAL  rear wheel drive              2.0
# 7               6.0            MANUAL  rear wheel drive              2.0
# 8               6.0            MANUAL  rear wheel drive              2.0
# 9               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
# 5                     Luxury,Performance      Compact         Coupe
# 6                     Luxury,Performance      Compact   Convertible
# 7                Luxury,High-Performance      Compact         Coupe
# 8                                 Luxury      Compact   Convertible
# 9                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500
# 5           28        18        3916  31200
# 6           26        17        3916  44100
# 7           28        20        3916  39300
# 8           28        18        3916  36900
# 9           27        18        3916  37200

# %%
randIdx = np.random.randint(data.shape[0], size=25)
data.iloc[randIdx,:]
# Out:
#                 Make                  Model  Year  \
# 3789      Mitsubishi                Eclipse  2012
# 2389         Porsche                 Cayman  2015
# 11811         Toyota                  Yaris  2015
# 302          Ferrari                    360  2004
# 3610           Dodge                Durango  2015
# 10859         Nissan                  Truck  1996
# 7277           Lexus                NX 200t  2016
# 514              BMW  5 Series Gran Turismo  2017
# 969          Porsche                    911  2017
# 174    Mercedes-Benz              300-Class  1991
# 11457         Subaru                    WRX  2015
# 6940           Dodge                 Monaco  1990
# 11270         Toyota                  Venza  2013
# 1114            Audi                     A6  2017
# 3920           Buick                Enclave  2015
# 11604          Volvo                   XC60  2017
# 3133          Subaru              Crosstrek  2017
# 6804      Mitsubishi      Mighty Max Pickup  1995
# 1473            Ford                 Aspire  1996
# 10006          Dodge                Stratus  2004
# 9745         Hyundai                 Sonata  2017
# 1185         Hyundai                 Accent  2016
# 6207           Dodge                Journey  2017
# 2846        Chrysler               Concorde  2004
# 2484           Dodge                Charger  2015
#
#                      Engine Fuel Type  Engine HP  Engine Cylinders  \
# 3789   premium unleaded (recommended)      265.0               6.0
# 2389      premium unleaded (required)      275.0               6.0
# 11811                regular unleaded      106.0               4.0
# 302       premium unleaded (required)      400.0               8.0
# 3610                 regular unleaded      290.0               6.0
# 10859                regular unleaded      134.0               4.0
# 7277      premium unleaded (required)      235.0               4.0
# 514       premium unleaded (required)      445.0               8.0
# 969       premium unleaded (required)      420.0               6.0
# 174                            diesel      121.0               5.0
# 11457  premium unleaded (recommended)      268.0               4.0
# 6940                 regular unleaded      150.0               6.0
# 11270                regular unleaded      268.0               6.0
# 1114   premium unleaded (recommended)      252.0               4.0
# 3920                 regular unleaded      288.0               6.0
# 11604                regular unleaded      240.0               4.0
# 3133                 regular unleaded      148.0               4.0
# 6804                 regular unleaded      116.0               4.0
# 1473                 regular unleaded       63.0               4.0
# 10006                regular unleaded      200.0               6.0
# 9745                 regular unleaded      245.0               4.0
# 1185                 regular unleaded      137.0               4.0
# 6207                 regular unleaded      173.0               4.0
# 2846                 regular unleaded      200.0               6.0
# 2484                 regular unleaded      370.0               8.0
#
#       Transmission Type      Driven_Wheels  Number of Doors  \
# 3789          AUTOMATIC  front wheel drive              2.0
# 2389             MANUAL   rear wheel drive              2.0
# 11811            MANUAL  front wheel drive              4.0
# 302    AUTOMATED_MANUAL   rear wheel drive              2.0
# 3610          AUTOMATIC   rear wheel drive              4.0
# 10859            MANUAL   four wheel drive              2.0
# 7277          AUTOMATIC    all wheel drive              4.0
# 514           AUTOMATIC    all wheel drive              4.0
# 969              MANUAL    all wheel drive              2.0
# 174           AUTOMATIC   rear wheel drive              4.0
# 11457            MANUAL    all wheel drive              4.0
# 6940          AUTOMATIC  front wheel drive              4.0
# 11270         AUTOMATIC    all wheel drive              4.0
# 1114          AUTOMATIC    all wheel drive              4.0
# 3920          AUTOMATIC    all wheel drive              4.0
# 11604         AUTOMATIC  front wheel drive              4.0
# 3133          AUTOMATIC    all wheel drive              4.0
# 6804             MANUAL   rear wheel drive              2.0
# 1473             MANUAL  front wheel drive              2.0
# 10006            MANUAL  front wheel drive              2.0
# 9745          AUTOMATIC  front wheel drive              4.0
# 1185          AUTOMATIC  front wheel drive              4.0
# 6207          AUTOMATIC  front wheel drive              4.0
# 2846          AUTOMATIC  front wheel drive              4.0
# 2484          AUTOMATIC   rear wheel drive              4.0
#
#                     Market Category Vehicle Size        Vehicle Style  \
# 3789          Hatchback,Performance      Compact        2dr Hatchback
# 2389        Luxury,High-Performance      Compact                Coupe
# 11811                     Hatchback      Compact        4dr Hatchback
# 302         Exotic,High-Performance      Compact                Coupe
# 3610          Crossover,Performance        Large              4dr SUV
# 10859                           NaN      Compact  Extended Cab Pickup
# 7277               Crossover,Luxury      Midsize              4dr SUV
# 514    Hatchback,Luxury,Performance        Large        4dr Hatchback
# 969         Luxury,High-Performance      Compact                Coupe
# 174                   Diesel,Luxury      Midsize                Sedan
# 11457                   Performance      Compact                Sedan
# 6940                            NaN      Midsize                Sedan
# 11270         Crossover,Performance      Midsize                Wagon
# 1114                         Luxury      Midsize                Sedan
# 3920                      Crossover      Midsize              4dr SUV
# 11604              Crossover,Luxury      Midsize              4dr SUV
# 3133                      Crossover      Compact              4dr SUV
# 6804                            NaN      Compact   Regular Cab Pickup
# 1473                      Hatchback      Compact        2dr Hatchback
# 10006                   Performance      Midsize                Coupe
# 9745                    Performance      Midsize                Sedan
# 1185                      Hatchback      Compact        4dr Hatchback
# 6207                      Crossover      Midsize              4dr SUV
# 2846                            NaN        Large                Sedan
# 2484               High-Performance        Large                Sedan
#
#        highway MPG  city mpg  Popularity    MSRP
# 3789            25        17         436   29089
# 2389            30        20        1715   52600
# 11811           37        30        2031   16820
# 302             15        10        2774  157767
# 3610            25        18        1851   36895
# 10859           18        15        2009    2647
# 7277            27        22         454   38465
# 514             24        15        3916   72500
# 969             28        20        1715  122600
# 174             30        23         617    2000
# 11457           28        21         640   26295
# 6940            24        15        1851    2000
# 11270           25        18        2031   31120
# 1114            31        22        3105   53800
# 3920            22        16         155   49305
# 11604           30        23         870   40950
# 3133            33        26         640   23495
# 6804            23        18         436    2000
# 1473            38        29        5657    2000
# 10006           26        18        1851   22695
# 9745            31        22        1439   26600
# 1185            37        26        1439   16195
# 6207            25        19        1851   20995
# 2846            27        19        1013   23480
# 2484            25        16        1851   36595

# %% [markdown]
# Выводим статистику по числовым показателям

# %%
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %% [markdown]
# Сгрупируйте данные по столбцу Setosa - в какой выборке?

# %% [markdown]
# Уточнить, в какой выборке, исправление конфликта
