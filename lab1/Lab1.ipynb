# %% [markdown]
# # Домашнее задание
# 1. Загрузить выборку `car.csv`
# 2. В качестве упражнения выведите на экран название (Make) марки и (Model) модель входит в интервал год выпуска (Year) с 2013 по 2015
# 3. Выводим первый и третий столбцы, сначала по отдельности, потом вместе.
# 4. Вывести 10 первых строк, вывести 23 случайных строк.
# 5. Вывести статистику по числовым показателям
# 6. Сгрупировать данные по столбцу Make, Year

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# __Загрузить выборку car.csv__

# %%
data=pd.read_csv('../dataset/car.csv', delimiter=',')
# data=pd.read_csv('../dataset/car.csv', delimiter=',').dropna()
# data = data.drop(['Market Category'], axis=1)

# %%
data['Market Category'] = data['Market Category'].str.replace('Hatchback', '')
data['Market Category'] = data['Market Category'].str.replace('High-Performance', '')
data['Market Category'] = data['Market Category'].str.replace('Performance', '')
data['Market Category'] = data['Market Category'].str.replace('Crossover', '')
data['Market Category'] = data['Market Category'].str.replace('Factory Tuner', '')
data['Market Category'] = data['Market Category'].str.replace(',,', ',')
# data['Market Category'] = data['Market Category'].str[:-1] if data['Market Category'].str.endswith(',') else data['Market Category']
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %% [markdown]
# __В качестве упражнения выведите на экран название (Make) марки и (Model) модель входит в интервал год выпуска (Year) с 2013 по 2015__

# %%
# фильтруем данные по условию года выпуска
filtered_data = data[(data['Year'] >= 2013) & (data['Year'] <= 2015)]
# выбираем только столбцы "Make" и "Model"
filtered_data[['Make', 'Model']]
# Out:
#         Make     Model
# 9        BMW  1 Series
# 10       BMW  1 Series
# 11       BMW  1 Series
# 12       BMW  1 Series
# 13       BMW  1 Series
# ...      ...       ...
# 11896    BMW        Z4
# 11897    BMW        Z4
# 11898    BMW        Z4
# 11899    BMW        Z4
# 11912  Acura       ZDX
#
# [3125 rows x 2 columns]

# %% [markdown]
# __Выводим первый и третий столбцы, сначала по отдельности, потом вместе.__

# %%
data.iloc[:,1]
# Out:
# 0        1 Series M
# 1          1 Series
# 2          1 Series
# 3          1 Series
# 4          1 Series
#             ...
# 11909           ZDX
# 11910           ZDX
# 11911           ZDX
# 11912           ZDX
# 11913        Zephyr
# Name: Model, Length: 11914, dtype: object

# %%
data.iloc[:,3]
# Out:
# 0           premium unleaded (required)
# 1           premium unleaded (required)
# 2           premium unleaded (required)
# 3           premium unleaded (required)
# 4           premium unleaded (required)
#                       ...
# 11909       premium unleaded (required)
# 11910       premium unleaded (required)
# 11911       premium unleaded (required)
# 11912    premium unleaded (recommended)
# 11913                  regular unleaded
# Name: Engine Fuel Type, Length: 11914, dtype: object

# %%
data.iloc[:,[1,3]]
# Out:
#             Model                Engine Fuel Type
# 0      1 Series M     premium unleaded (required)
# 1        1 Series     premium unleaded (required)
# 2        1 Series     premium unleaded (required)
# 3        1 Series     premium unleaded (required)
# 4        1 Series     premium unleaded (required)
# ...           ...                             ...
# 11909         ZDX     premium unleaded (required)
# 11910         ZDX     premium unleaded (required)
# 11911         ZDX     premium unleaded (required)
# 11912         ZDX  premium unleaded (recommended)
# 11913      Zephyr                regular unleaded
#
# [11914 rows x 2 columns]

# %% [markdown]
# Вывести 10 первых строк, вывести 23 случайных строк.

# %%
data.iloc[:10,:]
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
randIdx = np.random.randint(data.shape[0], size=25)
data.iloc[randIdx,:]
# Out:
#              Make                  Model  Year  \
# 5198      Pontiac                     G6  2009
# 4718        Honda                    Fit  2016
# 7578       Toyota                 Pickup  1994
# 403         Mazda                      3  2017
# 4120     Cadillac           Escalade ESV  2016
# 11039      Toyota                 Tundra  2017
# 9651        Buick                Skylark  1996
# 808          Saab            9-3 Griffin  2012
# 4914         Ford               Freestar  2005
# 8908        Volvo                    S60  2016
# 5254      Hyundai          Genesis Coupe  2016
# 10275        Ford               Taurus X  2008
# 8215        Dodge              Ram Wagon  2000
# 11361      Nissan                  Versa  2017
# 9247       Toyota                 Sienna  2017
# 1827   Volkswagen     Beetle Convertible  2015
# 5166     Infiniti                    G37  2009
# 590          FIAT                   500X  2016
# 2822     Plymouth                   Colt  1992
# ...

# %% [markdown]
# Выводим статистику по числовым показателям

# %% [markdown]
# [pandas.DataFrame.describe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
#
# * count - количество наблюдений, отличных от NA/нулевых.
# * max - максимум значений в объекте.
# * min - минимум значений в объекте.
# * mean- среднее значение.
# * std - стандартное отклонение наблюдений.
# * select_dtypes - подмножество DataFrame, включающее/исключающее столбцы в зависимости от их типа d.
#
# Процентиль — значение, которое заданная случайная величина не превышает с фиксированной вероятностью, заданной в процентах.
# Для числовых данных индекс результата будет включать count, mean, std, min, maxа также нижний 50и верхний процентили. По умолчанию нижний процентиль равен 25, а верхний процентиль равен 75. Процентиль 50аналогичен медиане.

# %%
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %% [markdown]
# * В столбцах "Engine HP", "Engine Cylinders", "Number of Doors" есть пропуски данных, потому что count меньше чем размер выборки
# * В столбце Engine Cylinders есть значения 0.0, что также можно считать отсутствием данных

# %%
# статистика по столбцам с текстовыми занчениями

data.describe(include="O")
# Out:
#              Make           Model  Engine Fuel Type Transmission Type  \
# count       11914           11914             11911             11914
# unique         48             915                10                 5
# top     Chevrolet  Silverado 1500  regular unleaded         AUTOMATIC
# freq         1123             156              7172              8266
#
#             Driven_Wheels Market Category Vehicle Size Vehicle Style
# count               11914            8172        11914         11914
# unique                  4              31            3            16
# top     front wheel drive                      Compact         Sedan
# freq                 4787            2551         4764          3048

# %% [markdown]
# [pandas.DataFrame.groupby](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)
#
#
# as_index bool, по умолчанию True - Возвращает объект с групповыми метками в качестве индекса. Актуально только для ввода DataFrame.

# %%
data.groupby(by=['Make'],as_index=False).min(numeric_only=True)['MSRP'].mean()
# Out:
# 72609.27083333333

# %%
data.groupby(by=['Make'],as_index=False).max(numeric_only=True)
# Out:
#              Make  Year  Engine HP  Engine Cylinders  Number of Doors  \
# 0           Acura  2017      573.0               6.0              4.0
# 1      Alfa Romeo  2016      237.0               4.0              2.0
# 2    Aston Martin  2016      568.0              12.0              4.0
# 3            Audi  2017      610.0              12.0              4.0
# 4             BMW  2017      600.0              12.0              4.0
# 5         Bentley  2016      631.0              12.0              4.0
# 6         Bugatti  2009     1001.0              16.0              2.0
# 7           Buick  2017      310.0               8.0              4.0
# 8        Cadillac  2017      640.0               8.0              4.0
# 9       Chevrolet  2017      650.0               8.0              4.0
# 10       Chrysler  2017      385.0               8.0              4.0
# 11          Dodge  2017      707.0              10.0              4.0
# ...

# %%
data.groupby(by=['Transmission Type'],as_index=True).min(numeric_only=True)
# Out:
#                    Year  Engine HP  Engine Cylinders  Number of Doors  \
# Transmission Type
# AUTOMATED_MANUAL   2002      120.0               4.0              2.0
# AUTOMATIC          1990       73.0               3.0              2.0
# DIRECT_DRIVE       2012       66.0               0.0              2.0
# MANUAL             1990       55.0               3.0              2.0
# UNKNOWN            1991      100.0               4.0              2.0
#
#                    highway MPG  city mpg  Popularity   MSRP
# Transmission Type
# AUTOMATED_MANUAL            12         7         113  19050
# AUTOMATIC                   12         9          21   2000
# DIRECT_DRIVE                43        47         436  22995
# MANUAL                      12         8           2   2000
# UNKNOWN                     17        12          26   2000

# %%
data.groupby(by=['Transmission Type'],as_index=True).max(numeric_only=True)
# Out:
#                    Year  Engine HP  Engine Cylinders  Number of Doors  \
# Transmission Type
# AUTOMATED_MANUAL   2017     1001.0              16.0              4.0
# AUTOMATIC          2017      707.0              12.0              4.0
# DIRECT_DRIVE       2017      200.0               4.0              4.0
# MANUAL             2017      707.0              12.0              4.0
# UNKNOWN            2000      305.0               8.0              4.0
#
#                    highway MPG  city mpg  Popularity     MSRP
# Transmission Type
# AUTOMATED_MANUAL           354        42        5657  2065902
# AUTOMATIC                   53        58        5657  1382750
# DIRECT_DRIVE               111       137        5657   134500
# MANUAL                      46        36        5657   440000
# UNKNOWN                     29        21        1851     9567

# %%
data.groupby(by=['Engine Cylinders'],as_index=True).min(numeric_only=True)
# Out:
#                   Year  Engine HP  Number of Doors  highway MPG  city mpg  \
# Engine Cylinders
# 0.0               2013      140.0              2.0           74        78
# 3.0               1992       55.0              2.0           29        24
# 4.0               1990       62.0              2.0           15        14
# 5.0               1990      121.0              2.0           18        13
# 6.0               1990      116.0              2.0           13        11
# 8.0               1990      125.0              2.0           12         9
# 10.0              2004      310.0              2.0           15         9
# 12.0              1992      322.0              2.0           12         7
# 16.0              2008     1001.0              2.0           14         8
#
#                   Popularity     MSRP
# Engine Cylinders
# 0.0                      617    25120
# 3.0                      436     2000
# 4.0                       26     2000
# ...

# %%
data.groupby(by=['Engine Cylinders'],as_index=True).max(numeric_only=True)
# Out:
#                   Year  Engine HP  Number of Doors  highway MPG  city mpg  \
# Engine Cylinders
# 0.0               2017      177.0              4.0          111       137
# 3.0               2017      123.0              4.0           44        37
# 4.0               2017      375.0              4.0          354        58
# 5.0               2016      360.0              4.0           33        24
# 6.0               2017      600.0              4.0           39        32
# 8.0               2017      707.0              4.0           29        20
# 10.0              2017      645.0              4.0           22        15
# 12.0              2017      750.0              4.0           22        14
# 16.0              2009     1001.0              2.0           14         8
#
#                   Popularity     MSRP
# Engine Cylinders
# 0.0                     5657   134500
# 3.0                     5657    18175
# 4.0                     5657    74995
# ...

# %%
data.groupby(by=['Market Category'],as_index=False).min(numeric_only=True)
# Out:
#              Market Category  Year  Engine HP  Engine Cylinders  \
# 0                             1990       55.0               0.0
# 1                          ,  1991      140.0               4.0
# 2                         ,,  2015      211.0               4.0
# 3                    ,Diesel  2009      150.0               4.0
# 4            ,Exotic,Luxury,  2017      345.0               6.0
# 5                 ,Flex Fuel  2010      160.0               4.0
# 6                ,Flex Fuel,  2015      280.0               4.0
# 7          ,Flex Fuel,Luxury  2010      220.0               4.0
# 8         ,Flex Fuel,Luxury,  2011      403.0               8.0
# 9                    ,Hybrid  2008       98.0               4.0
# 10                   ,Luxury  1996      140.0               0.0
# 11                  ,Luxury,  1990      160.0               4.0
# 12            ,Luxury,Diesel  2008      180.0               4.0
# 13            ,Luxury,Hybrid  2006      134.0               4.0
# ...
